# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report,confusion_matrix

# %%
df = pd.read_csv('https://github.com/MyungKyuYi/AI-class/raw/refs/heads/main/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X = df.drop(columns = ['Outcome']).values
y = df['Outcome'].values

# %%
X
# Out:
# array([[  6.   , 148.   ,  72.   , ...,  33.6  ,   0.627,  50.   ],
#        [  1.   ,  85.   ,  66.   , ...,  26.6  ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,  23.3  ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,  26.2  ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,  30.1  ,   0.349,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,  30.4  ,   0.315,  23.   ]])

# %%
Y = pd.get_dummies(y).values
Y
# Out:
# array([[False,  True],
#        [ True, False],
#        [False,  True],
#        ...,
#        [ True, False],
#        [False,  True],
#        [ True, False]])

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 1557)
print("학습 데이터 개수:", len(X_train))
print("테스트 데이터 개수:", len(X_test))

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# 학습 데이터 개수: 614
# 테스트 데이터 개수: 154
# (614, 8) (154, 8)
# (614, 2) (154, 2)

# %%
model = Sequential()

model.add(Dense(10, input_shape = (8, ), activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(6, activation = 'relu'))
model.add(Dense(2, activation = 'sigmoid'))

model.compile(Adam(learning_rate = 0.04), loss = 'binary_crossentropy', metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 10)                90
#
#  dense_29 (Dense)            (None, 8)                 88
#
#  dense_30 (Dense)            (None, 6)                 54
#
#  dense_31 (Dense)            (None, 2)                 14
#
# =================================================================
# Total params: 246
# Trainable params: 246
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history = model.fit(X_train, y_train, epochs = 30, batch_size = 32, validation_split = 0.1)
# Out:
# Epoch 1/30
# 18/18 [==============================] - 1s 14ms/step - loss: 0.6199 - accuracy: 0.6141 - val_loss: 0.5050 - val_accuracy: 0.6935
# Epoch 2/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5413 - accuracy: 0.6612 - val_loss: 0.4759 - val_accuracy: 0.6613
# Epoch 3/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4824 - accuracy: 0.7609 - val_loss: 0.4899 - val_accuracy: 0.7258
# Epoch 4/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4636 - accuracy: 0.7627 - val_loss: 0.4319 - val_accuracy: 0.8065
# Epoch 5/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4731 - accuracy: 0.7717 - val_loss: 0.4445 - val_accuracy: 0.7742
# Epoch 6/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4486 - accuracy: 0.7808 - val_loss: 0.4304 - val_accuracy: 0.7903
# Epoch 7/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4448 - accuracy: 0.7899 - val_loss: 0.4428 - val_accuracy: 0.7742
# Epoch 8/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4343 - accuracy: 0.7899 - val_loss: 0.4280 - val_accuracy: 0.7742
# Epoch 9/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4385 - accuracy: 0.7971 - val_loss: 0.5495 - val_accuracy: 0.7742
# Epoch 10/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4573 - accuracy: 0.7935 - val_loss: 0.4373 - val_accuracy: 0.7581
# Epoch 11/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4271 - accuracy: 0.7862 - val_loss: 0.4429 - val_accuracy: 0.7903
# Epoch 12/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4080 - accuracy: 0.8025 - val_loss: 0.4767 - val_accuracy: 0.8065
# Epoch 13/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4128 - accuracy: 0.7971 - val_loss: 0.4489 - val_accuracy: 0.8065
# Epoch 14/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4029 - accuracy: 0.8025 - val_loss: 0.4305 - val_accuracy: 0.8065
# Epoch 15/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3868 - accuracy: 0.8116 - val_loss: 0.4603 - val_accuracy: 0.7903
# Epoch 16/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3844 - accuracy: 0.8152 - val_loss: 0.4697 - val_accuracy: 0.8226
# Epoch 17/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3772 - accuracy: 0.8188 - val_loss: 0.4520 - val_accuracy: 0.8226
# Epoch 18/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3857 - accuracy: 0.8152 - val_loss: 0.4149 - val_accuracy: 0.7903
# Epoch 19/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3632 - accuracy: 0.8207 - val_loss: 0.4417 - val_accuracy: 0.7903
# Epoch 20/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3691 - accuracy: 0.8116 - val_loss: 0.4651 - val_accuracy: 0.8065
# Epoch 21/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3978 - accuracy: 0.8188 - val_loss: 0.4602 - val_accuracy: 0.7419
# Epoch 22/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3589 - accuracy: 0.8315 - val_loss: 0.4699 - val_accuracy: 0.8387
# Epoch 23/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3590 - accuracy: 0.8315 - val_loss: 0.4141 - val_accuracy: 0.8548
# Epoch 24/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3621 - accuracy: 0.8315 - val_loss: 0.4317 - val_accuracy: 0.8226
# Epoch 25/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3549 - accuracy: 0.8406 - val_loss: 0.4485 - val_accuracy: 0.8226
# Epoch 26/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3495 - accuracy: 0.8424 - val_loss: 0.4176 - val_accuracy: 0.8226
# Epoch 27/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3578 - accuracy: 0.8261 - val_loss: 0.4320 - val_accuracy: 0.8226
# Epoch 28/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3464 - accuracy: 0.8406 - val_loss: 0.4926 - val_accuracy: 0.8065
# Epoch 29/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3396 - accuracy: 0.8388 - val_loss: 0.5074 - val_accuracy: 0.8065
# Epoch 30/30
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3395 - accuracy: 0.8351 - val_loss: 0.4880 - val_accuracy: 0.8065

# %%
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test, axis = 1)
y_pred_class = np.argmax(y_pred, axis = 1)
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
loss = model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.84      0.78        97
#            1       0.64      0.49      0.55        57
#
#     accuracy                           0.71       154
#    macro avg       0.69      0.66      0.67       154
# weighted avg       0.70      0.71      0.70       154
#
# [[81 16]
#  [29 28]]
