# %%
import tensorflow as tf
from keras import datasets, models
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
import seaborn as sns

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
model = models.Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8629 - loss: 0.4697 - val_accuracy: 0.9600 - val_loss: 0.1368
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9658 - loss: 0.1177 - val_accuracy: 0.9676 - val_loss: 0.1067
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9762 - loss: 0.0755 - val_accuracy: 0.9687 - val_loss: 0.1131
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9819 - loss: 0.0569 - val_accuracy: 0.9725 - val_loss: 0.0952
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 9ms/step - accuracy: 0.9874 - loss: 0.0395 - val_accuracy: 0.9731 - val_loss: 0.0948

# %%
loss, acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {acc:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9699 - loss: 0.1016
# Test accuracy: 0.9752

# %%
y_pred = model.predict(test_images)
y_pred_labels = np.argmax(y_pred, axis=1)

y_true = test_labels

cm = confusion_matrix(y_true, y_pred_labels)

plt.figure(figsize=(10, 8))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
print(classification_report(y_true, y_pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.96      0.97      1032
#            3       0.96      0.98      0.97      1010
#            4       0.98      0.98      0.98       982
#            5       0.99      0.96      0.97       892
#            6       0.98      0.98      0.98       958
#            7       0.96      0.98      0.97      1028
#            8       0.96      0.97      0.96       974
#            9       0.97      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.97      0.98     10000
# weighted avg       0.98      0.98      0.98     10000
